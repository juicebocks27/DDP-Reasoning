# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/sergiopaniego/RAG_local_tutorial/blob/main/example_rag.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Simple RAG example with Langchain, Ollama and and open-source LLM model
#
# In this example, we first connect to an LLM locally and make request to the LLM that Ollama is serving using LangChain. After that, we generate our RAG application from a PDF file and extract details from that document.
#
# <p align="center">
#   <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2023/07/langchain3.png" alt="Langchain Logo" width="20%">
#   <img src="https://bookface-images.s3.amazonaws.com/logos/ee60f430e8cb6ae769306860a9c03b2672e0eaf2.png" alt="Ollama Logo" width="20%">
# </p>
#
# Sources:
#
# * https://github.com/svpino/llm
# * https://github.com/AIAnytime/Gemma-7B-RAG-using-Ollama/blob/main/Ollama%20Gemma.ipynb
# * https://www.youtube.com/watch?v=-MexTC18h20&ab_channel=AIAnytime
# * https://www.youtube.com/watch?v=HRvyei7vFSM&ab_channel=Underfitted
#
#
# # Requirements
#
# * Ollama installed locally

# %% [markdown]
# # Install the requirements
#
# If an error is raised related to docarray, refer to this solution: https://stackoverflow.com/questions/76880224/error-using-using-docarrayinmemorysearch-in-langchain-could-not-import-docarray

# %%
import subprocess

# Define the packages to install
packages = [
    "langchain",
    "langchain_pinecone",
    "langchain[docarray]",
    "docarray",
    "pypdf",
    "langchain-ollama"
]

# Install packages silently without output
for package in packages:
    subprocess.run(['pip3', 'install', package], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# %%
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# all-minilm:l6-v2           1b226e2802db    45 MB     3 weeks ago
# llama3.1:8b                46e0c10c039e    4.9 GB    3 weeks ago
# mistral:latest             f974a74358d6    4.1 GB    3 weeks ago
# nomic-embed-text:latest    0a109f422b47    274 MB    3 weeks ago

# %% [markdown]
# # Select the LLM model to use
#
# The model must be downloaded locally to be used, so if you want to run llama3, you should run:
#
# ```
#
# ollama pull llama3
#
# ```
#
# Check the list of models available for Ollama here: https://ollama.com/library

# %%
#MODEL = "gpt-3.5-turbo"
#MODEL = "mixtral:8x7b"
#MODEL = "gemma:7b"
#MODEL = "llama2"
MODEL = "llama3.1:8b" # https://ollama.com/library/llama3

# %% [markdown]
# # We instantiate the LLM model and the Embedding model

# %%
from langchain_ollama import OllamaLLM, OllamaEmbeddings

# Replace MODEL with the desired model name, e.g., "llama-2"
model = OllamaLLM(model=MODEL)
embeddings = OllamaEmbeddings(model=MODEL)

# %%
# Invoke the model
response = model.invoke("Give me an inspirational quote")
print(response)
# Out:
# Here's one:
#
# "You don't have to be great to start, but you have to start to be great." - Zig Ziglar

# %%
model.invoke("What is 2+2?")
# Out:
# '2 + 2 = 4.'

# %% [markdown]
# ## Using a parser provided by LangChain, we can transform the LLM output to something more suitable to be read

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
response_from_model = model.invoke("Give me an inspirational quote")
parsed_response = parser.parse(response_from_model)
print(parsed_response)
# Out:
# Here's one:
#
# "You don't have to be great to start, but you have to start to be great." - Zig Ziglar

# %% [markdown]
# # We generate the template for the conversation with the instruct-based LLM
#
# We can create a template to structure the conversation effectively.
#
# This template allows us to provide some general context to the Language Learning Model (LLM), which will be utilized for every prompt. This ensures that the model has a consistent background understanding for all interactions.
#
# Additionally, we can include specific context relevant to the particular prompt. This helps the model understand the immediate scenario or topic before addressing the actual question. Following this specific context, we then present the actual question we want the model to answer.
#
# By using this approach, we enhance the model's ability to generate accurate and relevant responses based on both the general and specific contexts provided.

# %%
from langchain.prompts import PromptTemplate

template = """
Answer the question based on the context below. If you can't 
answer the question, answer with "I don't know".

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)
prompt.format(context="Here is some context", question="Here is a question")
# Out:
# '\nAnswer the question based on the context below. If you can\'t \nanswer the question, answer with "I don\'t know".\n\nContext: Here is some context\n\nQuestion: Here is a question\n'

# %% [markdown]
# The model can answer prompts based on the context:

# %%
formatted_prompt = prompt.format(context="My parents named me Sergio", question="What's your name?")
response_from_model = model.invoke(formatted_prompt)
parsed_response = parser.parse(response_from_model)
print(parsed_response)
# Out:
# My name is Sergio.

# %% [markdown]
# But it can't answer what is not provided as context:

# %%
formatted_prompt = prompt.format(context="My parents named me Sergio", question="What's my age?")
response_from_model = model.invoke(formatted_prompt)
parsed_response = parser.parse(response_from_model)
print(parsed_response)
# Out:
# I don't know. The context only mentions your name, but not any information about your age.

# %% [markdown]
# Even previously known info!

# %%
formatted_prompt = prompt.format(context="My parents named me Sergio", question="What is 2+2?")
response_from_model = model.invoke(formatted_prompt)
parsed_response = parser.parse(response_from_model)
print(parsed_response)
# Out:
# I don't know

# %% [markdown]
# # Load an example PDF to do Retrieval Augmented Generation (RAG)
#
# For the example, you can select your own PDF.

# %%
from langchain_community.document_loaders import PyPDFLoader


loader = PyPDFLoader("reasoning_dataset_without_explanation.pdf")
pages = loader.load_and_split()
#pages = loader.load()
pages
# Out:
# [Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Question 1:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: Which one of the following seating arrangements of the six representatives in chairs 1\nthrough 6 would NOT violate the stated conditions?\nOptions: [ "Klosnik, Poirier, Neri, Manley, Osata, Londi", "Klosnik, Londi, Manley, Poirier, Neri,\nOsata", "Klosnik, Londi, Manley, Osata, Poirier, Neri", "Klosnik, Osata, Poirier, Neri, Londi, Manley",\n"Klosnik, Neri, Londi, Osata, Manley, Poirier" ]\nAnswer: "Klosnik, Londi, Manley, Poirier, Neri, Osata"\nQuestion 2:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Londi sits immediately next to Poirier, which one of the following is a pair of\nrepresentatives who must sit immediately next to each other?\nOptions: [ "Klosnik and Osata", "Londi and Neri", "Londi and Osata", "Manley and Neri", "Manley and\nPoirier" ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Answer: "Klosnik and Osata"\nQuestion 3:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Klosnik sits directly between Londi and Poirier, then Manley must sit directly between\nOptions: [ "Londi and Neri", "Londi and Osata", "Neri and Osata", "Neri and Poirier", "Osata and\nPoirier" ]\nAnswer: "Londi and Osata"\nQuestion 4:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Neri sits immediately next to Manley, then Klosnik can sit directly between\nOptions: [ "Londi and Manley", "Londi and Poirier", "Neri and Osata", "Neri and Poirier", "Poirier and\nOsata" ]\nAnswer: Poirier and Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Question 5:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Londi sits immediately next to Manley, then which one of the following is a complete and\naccurate list of representatives any one of whom could also sit immediately next to Londi?\nOptions: [ "Klosnik", "Klosnik, Neri", "Neri, Poirier", "Klosnik, Osata, Poirier", "Klosnik, Neri, Osata,\nPoirier" ]\nAnswer: "Klosnik, Neri, Osata, Poirier"\nQuestion 6:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Londi sits immediately next to Neri, which one of the following statements must be\nfalse?\nOptions: [ "Klosnik sits immediately next to Osata.", "Londi sits immediately next to Manley.", "Osata\nsits immediately next to Poirier.", "Neri sits directly between Londi and Poirier.", "Osata sits directly\nbetween Klosnik and Manley." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Answer: "Osata sits immediately next to Poirier."\nQuestion 7:\nContext: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,\nPoirier. There are exactly six chairs evenly spaced around a circular table. The chairs are numbered\n1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair\nnumber 6. Each chair is occupied by exactly one of the representatives. The following conditions\napply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.\nKlosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata\ndoes not sit immediately next to Manley.\nQuestion: If Klosnik sits immediately next to Osata, then Londi CANNOT sit directly between\nOptions: [ "Klosnik and Manley", "Klosnik and Neri", "Manley and Neri", "Manley and Poirier", "Neri\nand Osata" ]\nAnswer: "Neri and Osata"\nQuestion 8:\nContext: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table\nnot necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second\nto the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the\nneighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.\nQuestion: Who sits second to the right of the person who sits third to the left of S2?\nOptions: ["S5", "S1", "S3", "S6", "None of these"\nAnswer: "S5"\nQuestion 9:\nContext: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table\nnot necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the\nneighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.\nQuestion: What is the position of S8 with respect to S7?\nOptions: ["Second to the left", "Third to the left", "Immediate left", "Third to the right", "None of\nthese"]\nAnswer: "Third to the left"\nQuestion 10:\nContext: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table\nnot necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second\nto the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the\nneighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.\nQuestion: How many persons sit between S5 and S8 when counted clockwise from S5?\nOptions: ["Two", "One", "Three", "Five", "None of these"]\nAnswer: "Five"\nQuestion 11:\nContext: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table\nnot necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second\nto the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the\nneighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.\nQuestion: Who sits opposite S6?\nOptions: ["S1", "S3", "S4", "S5", "None of these"]\nAnswer: "S3"\nQuestion 12:\nContext: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second\nto the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the\nneighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.\nQuestion: Who sits second to the right of S1?\nOptions: ["S2", "S4", "S5", "S7"]\nAnswer: "S5"\nQuestion 13:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has\nexactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following\nconditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: If the computer in office 3 was bought in an earlier year than the printer in office 3 was,\nthen which one of the following statements could be true?\nOptions: [ "The computer in office 2 was bought in 1987.", "The computer in office 2 was bought in\n1988.", "The computer in office 4 was bought in 1988.", "The printer in office 4 was bought in 1988.",\n"The printer in office 4 was bought in 1989." ]\nAnswer: "The computer in office 2 was bought in 1988."\nQuestion 14:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has\nexactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: Which one of the following statements could be true?\nOptions: [ "The printer in office 1 was bought in 1987.", "The computer in office 2 was bought in\n1987.", "The computer in office 3 was bought in 1989.", "The printer in office 4 was bought in 1988.",\n"The printer in office 4 was bought in 1989." ]\nAnswer: "The computer in office 3 was bought in 1989."\nQuestion 15:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has\nexactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following\nconditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: If as few of the eight machines as possible were bought in 1987, then what is the exact\nnumber of machines that were bought in 1987?\nOptions: [ "0", "1", "2", "3", "4" ]\nAnswer:  "0"\nQuestion 16:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following\nconditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: If the computer in office 4 was bought in 1988, then which one of the following statements\nmust be true?\nOptions: [ "The printer in office 1 was bought in 1988.", "The printer in office 1 was bought in 1989.",\n"The computer in office 2 was bought in 1988.", "The computer in office 3 was bought in 1987.",\n"The printer in office 4 was bought in 1989." ]\nAnswer: "The printer in office 1 was bought in 1989."\nQuestion 17:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has\nexactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following\nconditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: If the computer in office 3 was bought in 1988, then which one of the following statements\ncould be true?\nOptions: [ "The printer in office 1 was bought in 1988.", "The computer in office 2 was bought in\n1987.", "The printer in office 2 was bought in 1988.", "The computer in office 4 was bought in 1987.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='"The printer in office 4 was bought in 1989." ]\nAnswer:  "The printer in office 2 was bought in 1988."\nQuestion 18:\nContext: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has\nexactly one computer and exactly one printer. Each of these eight machines was bought in either\n1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following\nconditions: The computer in each office was bought either in an earlier year than or in the same year\nas the printer in that office. The computer in office 2 and the printer in office 1 were bought in the\nsame year. The computer in office 3 and the printer in office 4 were bought in the same year. The\ncomputer in office 2 and the computer in office 3 were bought in different years. The computer in\noffice 1 and the printer in office 3 were bought in 1988.\nQuestion: Suppose that the computer in office 2 and the computer in office 3 had been bought in the\nsame year as each other. If all of the other conditions remained the same, then which one of the\nfollowing machines could have been bought in 1989?\nOptions: [ "the printer in office 1", "the computer in office 2", "the printer in office 2", "the computer in\noffice 4", "the printer in office 4" ]\nAnswer:  "the printer in office 2"\nQuestion 19:\nContext: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001\nthrough 2008, exactly one of the employees joined the company.\nH joined the company before N.\nK joined the company before J.\nN and J joined the company before G.\nN joined the company before O.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='J joined the company before M.\nG joined the company before I.\nQuestion: Which one of the following CANNOT be true?\nOptions: ["H joined the company in 2001", "H joined the company in 2003", "G joined the company in\n2004", "M joined the company in 2004", "O joined the company in 2004"]\nAnswer: "G joined the company in 2004."\nQuestion 20:\nContext: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001\nthrough 2008, exactly one of the employees joined the company.\nH joined the company before N.\nK joined the company before J.\nN and J joined the company before G.\nN joined the company before O.\nJ joined the company before M.\nG joined the company before I.\nQuestion: If James joined the firm in 1962, which one of the following CANNOT be true?\nOptions: ["H joined the company in 2003", "M joined the company in 2003", "H joined the company\nin 2004", "N joined the company in 2004", "O joined the company in 2004"]\nAnswer: "O joined the company in 2004."\nQuestion 21:\nContext: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001\nthrough 2008, exactly one of the employees joined the company.\nH joined the company before N.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='K joined the company before J.\nN and J joined the company before G.\nN joined the company before O.\nJ joined the company before M.\nG joined the company before I.\nQuestion: Of the following, which one is the latest year in which James could have joined the firm?\nOptions: ["2002", "2003", "2004", "2005", "2006"]\nAnswer: "2005"\nQuestion 22:\nContext: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001\nthrough 2008, exactly one of the employees joined the company.\nH joined the company before N.\nK joined the company before J.\nN and J joined the company before G.\nN joined the company before O.\nJ joined the company before M.\nG joined the company before I.\nQuestion: If Owens joined the firm in 1965 and MacNeil joined it in 1967, one can determine the\nyears in which exactly how many of the other partners joined the firm?\nOptions: [ "1", "2", "3", "4", "5" ]\nAnswer: "2"\nQuestion 23:\nContext: The eight partners of a law firm are Gregg, Hodges, Ivan, James, King, MacNeil, Nader,\nand Owens. In each of the years 1961 through 1968, exactly one of the partners joined the firm.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Hodges joined the firm before Nader. King joined the firm before James. Nader and James joined\nthe firm before Gregg. Nader joined the firm before Owens. James joined the firm before MacNeil.\nGregg joined the firm before Ivan.\nQuestion: Assume that Owens joined the law firm before MacNeil. Of the following, which one is the\nearliest year in which MacNeil could have joined it?\nOptions: ["2003", "2004", "2005", "2006", "2007"]\nAnswer:  "2006"\nQuestion 24:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for\neach of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: If the line 3 tickets for January are red, then which one of the following statements must\nbe true?\nOptions: [ "The line 1 tickets for January are green.", "The line 1 tickets for January are yellow.",\n"The line 1 tickets for February are red.", "The line 2 tickets for February are yellow.", "The line 3\ntickets for February are green." ]\nAnswer: "The line 3 tickets for February are green." \nQuestion 25:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 12}, page_content='each of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: If one set of the line 2 tickets is green, then which one of the following statements must be\ntrue?\nOptions: [ "The line 1 tickets for January are red.", "The line 3 tickets for January are red.", "The line\n1 tickets for February are red.", "The line 3 tickets for February are green.", "The line 3 tickets for\nFebruary are yellow." ]\nAnswer:  "The line 1 tickets for January are red."\nQuestion 26:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for\neach of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: Which one of the following statements could be true?\nOptions: [ "No January ticket is green.", "No February ticket is green.", "Only line 2 tickets are red.",\n"One set of January tickets is green and one set of January tickets is yellow.", "The line 2 tickets for\nJanuary are the same color as the line 1 tickets for February." ]\nAnswer: "No January ticket is green."'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 13}, page_content='Question 27:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for\neach of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: Which one of the following statements could be true?\nOptions: [ "Both the line 1 tickets for January and the line 2 tickets for February are green.", "Both\nthe line 1 tickets for January and the line 2 tickets for February are yellow.", "Both the line 1 tickets\nfor January and the line 3 tickets for February are yellow.", "The line 1 tickets for January are green,\nand the line 3 tickets for February are red.", "The line 3 tickets for January are yellow, and the line 1\ntickets for February are red." ]\nAnswer: "Both the line 1 tickets for January and the line 2 tickets for February are yellow."\nQuestion 28:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for\neach of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: If the line 3 tickets for February are yellow, then each of the following statements must be'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='true EXCEPT:\nOptions: [ "One set of January tickets is green.", "One set of line 1 tickets is red.", "One set of line 2\ntickets is red.", "The tickets in two of the six sets are red.", "The tickets in two of the six sets are\nyellow." ]\nAnswer: "The tickets in two of the six sets are yellow."\nQuestion 29:\nContext: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints\nthree sets of tickets for January and three sets of tickets for February: one set for each of its lines for\neach of the two months. The company\'s tickets are printed in a manner consistent with the following\nconditions: Each of the six sets of tickets is exactly one of the following colors: green, purple, red,\nyellow. For each line, the January tickets are a different color than the February tickets. For each\nmonth, tickets for different lines are in different colors. Exactly one set of January tickets is red. For\nline 3, either the January tickets or the February tickets, but not both, are green. The January tickets\nfor line 2 are purple. No February tickets are purple.\nQuestion: Suppose that none of the ticket sets are purple. If all of the other conditions remain the\nsame, then which one of the following statements could be true?\nOptions: [ "None of the January tickets are green.", "None of the February tickets are green.", "None\nof the line 2 tickets are green.", "No line 1 or line 2 tickets are yellow.", "No line 2 or line 3 tickets are\nred." ]\nAnswer: "None of the line 2 tickets are green."\nQuestion 30:\nContext: For a standard dice with numbers from 1 to 6 (unless mentioned otherwise) answer the\nfollowing questions.\nQuestion: When a six-sided die rolls. What will be the probability of getting a prime number?\nAnswer: 0.5'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question 31:\nQuestion: Two six-sided dice are rolled, which is more likely to happen: the sum is equal to 10, or\nthe sum is equal to 11?\nAnswer: P (Sum is 10) > P (Sum is 11)\nQuestion 32:\nQuestion: When rolling two six-sided dice, what is the probability of getting a sum of 8?\nAnswer: "5/36"\nQuestion 33:\nQuestion: In a game with two eight-sided dice, what is the probability of rolling a double (both dice\nshowing the same number)?\nAnswer: "1/8"\nQuestion 34:\nQuestion: If a fair six-sided die is rolled four times, what is the probability of getting all different\nnumbers?\nAnswer: "5/18"\nQuestion 35:\nQuestion: When rolling two six-sided dice, what is the probability of getting a sum of 7?\nAnswer: "1/6"\nQuestion 36:\nQuestion: If you roll a fair six-sided die three times, what is the probability of getting at least one 6?\nAnswer: "91/216"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question 37:\nQuestion: In a game with three eight-sided dice, what is the probability of getting at least one even\nnumber?\nAnswer: "7/8"\nQuestion 38:\nQuestion: If you roll a fair six-sided die four times, what is the probability of getting at most one 2?\nAnswer: "125/144"\nQuestion 39:\nQuestion: If you roll three six-sided dice, what is the probability of getting at most two 4s?\nAnswer: "215/216"\nQuestion 40:\nContext: Answer the following questions for a standard deck of 52 cards.\nQuestion: A card is drawn from well shuffled deck of playing cart. Find the probability that the card\ndrawn is either a king or queen?\nAnswer: "2/13"\nQuestion 41:\nQuestion: From a deck of playing cards, one card is drawn randomly. What is the probability that the\ncard is red color or king?\nAnswer: "28/52"\nQuestion 42:\nQuestion: If two cards are drawn from a well-shuffled pack of 52 cards, the probability that they are\nof the same colour?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Answer: "25/51"\nQuestion 43:\nQuestion: A card is drawn at random from an ordinary deck of 52 playing cards. The probability that\nthe card is a 10 or a spade is:\nAnswer: "4/13"\nQuestion 44:\nQuestion: A man draws two cards from the deck of 52 cards such that the first drawn card is king,\nthen find the probability that the second card is also king?\nAnswer: "1/17"\nQuestion 45:\nQuestion: Find the number of ways of picking four cards from a set of 52 playing cards if four cards\nare of the same unit.\nAnswer: "2860"\nQuestion 46:\nQuestion: If a card is drawn from a pack of 52 cards, then the probability of getting a queen of club\nor king of heart is\nAnswer: "1/26"\nQuestion 47:\nQuestion: What is the probability of drawing a card which is neither red nor a face card?\nAnswer: "8/13"\nQuestion 48:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: What is the probability of drawing two cards from a deck of cards with replacement when\nthe first card is heart and second card is diamond?\nAnswer: "13/204"\nQuestion 49:\nQuestion: Find the probability of neither a heart nor a red king\nAnswer: "19/26"\nQuestion 50:\nQuestion: A player X has a biased coin whose probability of showing heads is p, and a player Y has\na fair coin. They start playing a game with their coins and play alternately. The player who throws a\nhead first is a winner. If X starts the game, and the probability of winning the game by both players\nis equal, then the value of \'p\' is\nAnswer: "1/3"\nQuestion 51:\nQuestion: The minimum number of times a fair coin must be tossed so that the probability of getting\nat least one head is more than 99% is:\nAnswer: "7"\nQuestion 52:\nQuestion: A coin is biased, so a head is twice as likely to occur as a tail. If the coin is tossed 3 times,\nthen the probability of getting two tails and one head is-\nAnswer: "2/9"\nQuestion 53:\nQuestion: A fair coin is tossed 6 times. What is the probability of getting a result in the 6th toss,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='different from those obtained in the first five tosses?\nAnswer: "1/32"\nQuestion 54:\nQuestion: An unbiased coin is tossed 3 times, if the third toss gets head what is the probability of\ngetting at least one more head?\nAnswer: "3/4"\nQuestion 55:\nQuestion: The number of possible outcomes, when a coin is tossed 6 times, is\nAnswer: "64"\nQuestion 56:\nQuestion: If a coin is tossed thrice, find the probability of getting one or two heads.\nAnswer: "3/4"\nQuestion 57:\nQuestion: A coin is tossed 3 times. The probability of getting a head and a tail alternately is:\nAnswer: "1/4"\nQuestion 58:\nQuestion: Four coins are tossed simultaneously. What is the probability of getting exactly 2 heads?\nAnswer: "3/8"\nQuestion 59:\nQuestion: Five coins are tossed once. What is the probability of getting at most four tails ?\nAnswer: "31/32"')]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text_documents = text_splitter.split_documents(pages)

text_documents
# Out:
# [Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Question 1:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Question: Which one of the following seating arrangements of the six representatives in chairs 1'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='through 6 would NOT violate the stated conditions?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Options: [ "Klosnik, Poirier, Neri, Manley, Osata, Londi", "Klosnik, Londi, Manley, Poirier, Neri,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Osata", "Klosnik, Londi, Manley, Osata, Poirier, Neri", "Klosnik, Osata, Poirier, Neri, Londi,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Neri, Londi, Manley",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='"Klosnik, Neri, Londi, Osata, Manley, Poirier" ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Answer: "Klosnik, Londi, Manley, Poirier, Neri, Osata"\nQuestion 2:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Question: If Londi sits immediately next to Poirier, which one of the following is a pair of'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='representatives who must sit immediately next to each other?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Options: [ "Klosnik and Osata", "Londi and Neri", "Londi and Osata", "Manley and Neri", "Manley and'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 0}, page_content='Poirier" ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Answer: "Klosnik and Osata"\nQuestion 3:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Question: If Klosnik sits directly between Londi and Poirier, then Manley must sit directly between'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Options: [ "Londi and Neri", "Londi and Osata", "Neri and Osata", "Neri and Poirier", "Osata and'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Poirier" ]\nAnswer: "Londi and Osata"\nQuestion 4:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Question: If Neri sits immediately next to Manley, then Klosnik can sit directly between'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Options: [ "Londi and Manley", "Londi and Poirier", "Neri and Osata", "Neri and Poirier", "Poirier'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Poirier", "Poirier and'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 1}, page_content='Osata" ]\nAnswer: Poirier and Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Question 5:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Question: If Londi sits immediately next to Manley, then which one of the following is a complete'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='is a complete and'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='accurate list of representatives any one of whom could also sit immediately next to Londi?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Options: [ "Klosnik", "Klosnik, Neri", "Neri, Poirier", "Klosnik, Osata, Poirier", "Klosnik, Neri,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='"Klosnik, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Poirier" ]\nAnswer: "Klosnik, Neri, Osata, Poirier"\nQuestion 6:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Question: If Londi sits immediately next to Neri, which one of the following statements must be'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='false?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='Options: [ "Klosnik sits immediately next to Osata.", "Londi sits immediately next to Manley.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='next to Manley.", "Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='sits immediately next to Poirier.", "Neri sits directly between Londi and Poirier.", "Osata sits'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='"Osata sits directly'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 2}, page_content='between Klosnik and Manley." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Answer: "Osata sits immediately next to Poirier."\nQuestion 7:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Context: Exactly six trade representatives negotiate a treaty: Klosnik, Londi, Manley, Neri, Osata,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Poirier. There are exactly six chairs evenly spaced around a circular table. The chairs are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='The chairs are numbered'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='1 through 6, with successively numbered chairs next to each other and chair number 1 next to chair'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='number 6. Each chair is occupied by exactly one of the representatives. The following conditions'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='apply: Poirier sits immediately next to Neri. Londi sits immediately next to Manley, Neri, or both.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Klosnik does not sit immediately next to Manley. If Osata sits immediately next to Poirier, Osata'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='does not sit immediately next to Manley.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Question: If Klosnik sits immediately next to Osata, then Londi CANNOT sit directly between'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Options: [ "Klosnik and Manley", "Klosnik and Neri", "Manley and Neri", "Manley and Poirier", "Neri'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='and Osata" ]\nAnswer: "Neri and Osata"\nQuestion 8:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Context: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='neighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Question: Who sits second to the right of the person who sits third to the left of S2?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Options: ["S5", "S1", "S3", "S6", "None of these"\nAnswer: "S5"\nQuestion 9:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='Context: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 3}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='neighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Question: What is the position of S8 with respect to S7?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Options: ["Second to the left", "Third to the left", "Immediate left", "Third to the right", "None'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='the right", "None of'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='these"]\nAnswer: "Third to the left"\nQuestion 10:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Context: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='neighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Question: How many persons sit between S5 and S8 when counted clockwise from S5?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Options: ["Two", "One", "Three", "Five", "None of these"]\nAnswer: "Five"\nQuestion 11:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Context: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='neighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Question: Who sits opposite S6?\nOptions: ["S1", "S3", "S4", "S5", "None of these"]\nAnswer: "S3"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Answer: "S3"\nQuestion 12:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 4}, page_content='Context: There are eight persons S1, S2, S3, S4, S5, S6, S7 and S8 sitting around a circular table'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='not necessarily in the same order. Each of the persons is facing towards the centre. S7 sits second'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='to the right of S3. S2 sits third to the left of S4, who is the neighbour of S7. S6 is neither the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='neighbour of S2 nor S7. Neither S1 is the neighbour of S2 nor S5 is the neighbour of S3.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Question: Who sits second to the right of S1?\nOptions: ["S2", "S4", "S5", "S7"]\nAnswer: "S5"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Answer: "S5"\nQuestion 13:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Question: If the computer in office 3 was bought in an earlier year than the printer in office 3'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='printer in office 3 was,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='then which one of the following statements could be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Options: [ "The computer in office 2 was bought in 1987.", "The computer in office 2 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='1988.", "The computer in office 4 was bought in 1988.", "The printer in office 4 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='4 was bought in 1988.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='"The printer in office 4 was bought in 1989." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Answer: "The computer in office 2 was bought in 1988."\nQuestion 14:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 5}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Question: Which one of the following statements could be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Options: [ "The printer in office 1 was bought in 1987.", "The computer in office 2 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='1987.", "The computer in office 3 was bought in 1989.", "The printer in office 4 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='4 was bought in 1988.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='"The printer in office 4 was bought in 1989." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Answer: "The computer in office 3 was bought in 1989."\nQuestion 15:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Question: If as few of the eight machines as possible were bought in 1987, then what is the exact'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='number of machines that were bought in 1987?\nOptions: [ "0", "1", "2", "3", "4" ]\nAnswer:  "0"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Answer:  "0"\nQuestion 16:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 6}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Question: If the computer in office 4 was bought in 1988, then which one of the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='of the following statements'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='must be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Options: [ "The printer in office 1 was bought in 1988.", "The printer in office 1 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1 was bought in 1989.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='"The computer in office 2 was bought in 1988.", "The computer in office 3 was bought in 1987.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='"The printer in office 4 was bought in 1989." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Answer: "The printer in office 1 was bought in 1989."\nQuestion 17:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Question: If the computer in office 3 was bought in 1988, then which one of the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='of the following statements'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='could be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='Options: [ "The printer in office 1 was bought in 1988.", "The computer in office 2 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='1987.", "The printer in office 2 was bought in 1988.", "The computer in office 4 was bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 7}, page_content='4 was bought in 1987.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='"The printer in office 4 was bought in 1989." ]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='Answer:  "The printer in office 2 was bought in 1988."\nQuestion 18:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='Context: A small software firm has four offices, numbered 1, 2, 3, and 4. Each of its offices has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='exactly one computer and exactly one printer. Each of these eight machines was bought in either'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='1987, 1988, or 1989. The eight machines were bought in a manner consistent with the following'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='conditions: The computer in each office was bought either in an earlier year than or in the same'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='than or in the same year'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='as the printer in that office. The computer in office 2 and the printer in office 1 were bought in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='1 were bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='same year. The computer in office 3 and the printer in office 4 were bought in the same year. The'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='computer in office 2 and the computer in office 3 were bought in different years. The computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='office 1 and the printer in office 3 were bought in 1988.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='Question: Suppose that the computer in office 2 and the computer in office 3 had been bought in the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='same year as each other. If all of the other conditions remained the same, then which one of the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='following machines could have been bought in 1989?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='Options: [ "the printer in office 1", "the computer in office 2", "the printer in office 2", "the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='in office 2", "the computer in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='office 4", "the printer in office 4" ]\nAnswer:  "the printer in office 2"\nQuestion 19:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='Context: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='through 2008, exactly one of the employees joined the company.\nH joined the company before N.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 8}, page_content='K joined the company before J.\nN and J joined the company before G.\nN joined the company before O.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='J joined the company before M.\nG joined the company before I.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Question: Which one of the following CANNOT be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Options: ["H joined the company in 2001", "H joined the company in 2003", "G joined the company in'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='2004", "M joined the company in 2004", "O joined the company in 2004"]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Answer: "G joined the company in 2004."\nQuestion 20:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Context: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='through 2008, exactly one of the employees joined the company.\nH joined the company before N.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='K joined the company before J.\nN and J joined the company before G.\nN joined the company before O.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='J joined the company before M.\nG joined the company before I.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Question: If James joined the firm in 1962, which one of the following CANNOT be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Options: ["H joined the company in 2003", "M joined the company in 2003", "H joined the company'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='in 2004", "N joined the company in 2004", "O joined the company in 2004"]'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Answer: "O joined the company in 2004."\nQuestion 21:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='Context: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 9}, page_content='through 2008, exactly one of the employees joined the company.\nH joined the company before N.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='K joined the company before J.\nN and J joined the company before G.\nN joined the company before O.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='J joined the company before M.\nG joined the company before I.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Question: Of the following, which one is the latest year in which James could have joined the firm?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Options: ["2002", "2003", "2004", "2005", "2006"]\nAnswer: "2005"\nQuestion 22:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Context: The eight employees of a company are G, H, I, J, K,M, N, and O. In each of the years 2001'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='through 2008, exactly one of the employees joined the company.\nH joined the company before N.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='K joined the company before J.\nN and J joined the company before G.\nN joined the company before O.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='J joined the company before M.\nG joined the company before I.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Question: If Owens joined the firm in 1965 and MacNeil joined it in 1967, one can determine the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='years in which exactly how many of the other partners joined the firm?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Options: [ "1", "2", "3", "4", "5" ]\nAnswer: "2"\nQuestion 23:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='Context: The eight partners of a law firm are Gregg, Hodges, Ivan, James, King, MacNeil, Nader,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 10}, page_content='and Owens. In each of the years 1961 through 1968, exactly one of the partners joined the firm.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Hodges joined the firm before Nader. King joined the firm before James. Nader and James joined'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='the firm before Gregg. Nader joined the firm before Owens. James joined the firm before MacNeil.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Gregg joined the firm before Ivan.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Question: Assume that Owens joined the law firm before MacNeil. Of the following, which one is the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='earliest year in which MacNeil could have joined it?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Options: ["2003", "2004", "2005", "2006", "2007"]\nAnswer:  "2006"\nQuestion 24:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='Context: A railway company has exactly three lines: line 1, line 2, and line 3. The company prints'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='three sets of tickets for January and three sets of tickets for February: one set for each of its'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 11}, page_content='set for each of its lines for'),
# ...
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='month, tickets for different lines are in different colors. Exactly one set of January tickets is'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='January tickets is red. For'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='line 3, either the January tickets or the February tickets, but not both, are green. The January'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='green. The January tickets'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='for line 2 are purple. No February tickets are purple.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='Question: Suppose that none of the ticket sets are purple. If all of the other conditions remain'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='conditions remain the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='same, then which one of the following statements could be true?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='Options: [ "None of the January tickets are green.", "None of the February tickets are green.",'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='are green.", "None'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='of the line 2 tickets are green.", "No line 1 or line 2 tickets are yellow.", "No line 2 or line 3'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='line 2 or line 3 tickets are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='red." ]\nAnswer: "None of the line 2 tickets are green."\nQuestion 30:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='Context: For a standard dice with numbers from 1 to 6 (unless mentioned otherwise) answer the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='following questions.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='Question: When a six-sided die rolls. What will be the probability of getting a prime number?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 14}, page_content='Answer: 0.5'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question 31:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: Two six-sided dice are rolled, which is more likely to happen: the sum is equal to 10, or'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='the sum is equal to 11?\nAnswer: P (Sum is 10) > P (Sum is 11)\nQuestion 32:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: When rolling two six-sided dice, what is the probability of getting a sum of 8?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Answer: "5/36"\nQuestion 33:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: In a game with two eight-sided dice, what is the probability of rolling a double (both'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='a double (both dice'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='showing the same number)?\nAnswer: "1/8"\nQuestion 34:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: If a fair six-sided die is rolled four times, what is the probability of getting all'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='of getting all different'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='numbers?\nAnswer: "5/18"\nQuestion 35:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: When rolling two six-sided dice, what is the probability of getting a sum of 7?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Answer: "1/6"\nQuestion 36:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Question: If you roll a fair six-sided die three times, what is the probability of getting at least'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='of getting at least one 6?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 15}, page_content='Answer: "91/216"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question 37:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: In a game with three eight-sided dice, what is the probability of getting at least one'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='at least one even'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='number?\nAnswer: "7/8"\nQuestion 38:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: If you roll a fair six-sided die four times, what is the probability of getting at most'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='of getting at most one 2?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Answer: "125/144"\nQuestion 39:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: If you roll three six-sided dice, what is the probability of getting at most two 4s?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Answer: "215/216"\nQuestion 40:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question 40:\nContext: Answer the following questions for a standard deck of 52 cards.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: A card is drawn from well shuffled deck of playing cart. Find the probability that the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='that the card'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='drawn is either a king or queen?\nAnswer: "2/13"\nQuestion 41:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: From a deck of playing cards, one card is drawn randomly. What is the probability that'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='probability that the'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='card is red color or king?\nAnswer: "28/52"\nQuestion 42:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='Question: If two cards are drawn from a well-shuffled pack of 52 cards, the probability that they'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='that they are'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 16}, page_content='of the same colour?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Answer: "25/51"\nQuestion 43:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Question: A card is drawn at random from an ordinary deck of 52 playing cards. The probability that'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='the card is a 10 or a spade is:\nAnswer: "4/13"\nQuestion 44:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Question: A man draws two cards from the deck of 52 cards such that the first drawn card is king,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='then find the probability that the second card is also king?\nAnswer: "1/17"\nQuestion 45:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Question: Find the number of ways of picking four cards from a set of 52 playing cards if four'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='cards if four cards'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='are of the same unit.\nAnswer: "2860"\nQuestion 46:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Question: If a card is drawn from a pack of 52 cards, then the probability of getting a queen of'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='getting a queen of club'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='or king of heart is\nAnswer: "1/26"\nQuestion 47:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Question: What is the probability of drawing a card which is neither red nor a face card?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 17}, page_content='Answer: "8/13"\nQuestion 48:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: What is the probability of drawing two cards from a deck of cards with replacement when'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='the first card is heart and second card is diamond?\nAnswer: "13/204"\nQuestion 49:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question 49:\nQuestion: Find the probability of neither a heart nor a red king\nAnswer: "19/26"'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Answer: "19/26"\nQuestion 50:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: A player X has a biased coin whose probability of showing heads is p, and a player Y has'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='a fair coin. They start playing a game with their coins and play alternately. The player who throws'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='player who throws a'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='head first is a winner. If X starts the game, and the probability of winning the game by both'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='the game by both players'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='is equal, then the value of \'p\' is\nAnswer: "1/3"\nQuestion 51:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: The minimum number of times a fair coin must be tossed so that the probability of getting'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='at least one head is more than 99% is:\nAnswer: "7"\nQuestion 52:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: A coin is biased, so a head is twice as likely to occur as a tail. If the coin is tossed'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='the coin is tossed 3 times,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='then the probability of getting two tails and one head is-\nAnswer: "2/9"\nQuestion 53:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='Question: A fair coin is tossed 6 times. What is the probability of getting a result in the 6th'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 18}, page_content='a result in the 6th toss,'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='different from those obtained in the first five tosses?\nAnswer: "1/32"\nQuestion 54:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question: An unbiased coin is tossed 3 times, if the third toss gets head what is the probability'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='is the probability of'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='getting at least one more head?\nAnswer: "3/4"\nQuestion 55:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question 55:\nQuestion: The number of possible outcomes, when a coin is tossed 6 times, is'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Answer: "64"\nQuestion 56:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question: If a coin is tossed thrice, find the probability of getting one or two heads.'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Answer: "3/4"\nQuestion 57:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question: A coin is tossed 3 times. The probability of getting a head and a tail alternately is:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Answer: "1/4"\nQuestion 58:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question: Four coins are tossed simultaneously. What is the probability of getting exactly 2 heads?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Answer: "3/8"\nQuestion 59:'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Question: Five coins are tossed once. What is the probability of getting at most four tails ?'),
#  Document(metadata={'source': 'reasoning_dataset_without_explanation.pdf', 'page': 19}, page_content='Answer: "31/32"')]

# %% [markdown]
# # Store the PDF in a vector space.
#
# From Langchain docs:
#
# `DocArrayInMemorySearch is a document index provided by Docarray that stores documents in memory. It is a great starting point for small datasets, where you may not want to launch a database server.`
#
# The execution time of the following block depends on the complexity and longitude of the PDF provided. Try to keep it small and simple for the example.

# %%
from langchain_community.vectorstores import DocArrayInMemorySearch

vectorstore = DocArrayInMemorySearch.from_documents(text_documents, embedding=embeddings)
# Out:
# C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydantic\_migration.py:283: UserWarning: `pydantic.error_wrappers:ValidationError` has been moved to `pydantic:ValidationError`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')

# %%
# Create retriever with a high relevance threshold or no filtering
# retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": len(text_documents)})
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 10})

# Retrieve all document chunks
retrieved_context = retriever.invoke("")  # Empty query to retrieve everything

# %%
import pandas as pd
from langchain.chains import LLMChain

# Load the Excel file
df = pd.read_excel('reasoning_dataset.xlsx', sheet_name='test')

# Create a prompt template
prompt = PromptTemplate(
    input_variables=["context", "question", "options"],
    template="""
    Question description: {context}
    Question: {question}
    Options: {options}

    Please answer the question based on the given information.
    """
)

# Create an LLMChain
chain = LLMChain(llm=model, prompt=prompt)

# Process each row in the DataFrame
for _, row in df.iterrows():
    context = row['context'] if not pd.isna(row['context']) else ""
    question = row['question'] if not pd.isna(row['question']) else ""
    options = row['options'] if not pd.isna(row['options']) else ""

    # Create a query for the retriever
    retriever_query = f"{context} {question} {options}"
    
    # Retrieve relevant context
    retrieved_context = retriever.invoke(retriever_query)

    # Combine the original context with the retrieved context
    combined_context = f"{context}\n\nAdditional context:\n{retrieved_context}"

    # Invoke the model
    response = chain.run(context=combined_context, question=question, options=options)

    print(f"Question description: {context}")
    print(f"Question: {question}")
    print(f"Options: {options}")
    print(f"Answer: {response}")
    print()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25856\957776799.py:38: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = chain.run(context=combined_context, question=question, options=options)
# Question description: Eight persons namely P, Q, R, S, T, U, V, and W are sitting around a circular table facing the centre of the table but not necessarily in the same order. P sits second to the right of U, who sits opposite to T. Two persons sit between Q and T. S sits third to the right of P. V sits second to the left of W.
# Question: How many persons sit between W and R when counted from the right of R?
# Options: ["Two", "Three", "Four", "One", "None of these"]
#
# Answer: To solve this problem, let's break down the given information:
#
# 1. P sits second to the right of U.
# 2. U sits opposite T (i.e., they are facing each other).
# 3. Two persons sit between Q and T.
# 4. S sits third to the right of P.
# 5. V sits second to the left of W.
#
# From statement 2, we know that U and T sit opposite each other. So, when counting from the right of R (i.e., moving clockwise), let's place T at the top-right position in our imaginary circular table.
#
# Now, based on the given statements:
#
# - P sits second to the right of U, which means P sits between U and T.
# - Two persons sit between Q and T, so they can't be together on either side of T. This implies that R must sit between two of them (either QR or TR), because there are no other positions left for such pairs. Therefore, we can determine the order as follows: UR...QRTVW.
# - S sits third to the right of P, which means S is not sitting at W's position, since if it were, then V would be sitting on the left side of R and there wouldn't be any space for Q or T between R and two other persons. Therefore, the correct order should have P on one end (let's assume from the top, since that is where U sits opposite to T), followed by UR...QRTSVW.
# - V sits second to the left of W.
#
# Counting from the right of R:
#
# Let's place the 8 persons around a table in this manner: P(U)...T(R)QSVW (imagine an empty space between 'P' and 'U', 'U' and 'T', etc. for proper seating arrangement).
#
# In the order above, if we count from R (at T), there are two persons sitting between W and R when counted from the right of R.
#
# Therefore, the correct answer is: "Two".
#
# Question description: Eight persons namely P, Q, R, S, T, U, V, and W are sitting around a circular table facing the centre of the table but not necessarily in the same order. P sits second to the right of U, who sits opposite to T. Two persons sit between Q and T. S sits third to the right of P. V sits second to the left of W.
# Question: If all the persons sit alphabetically starting from P in clockwise direction, then how many will remain unchanged (except for P)?
# Options: ["None", "One", "Two", "Three", "None of these"]
# Answer: Let's analyze the given information:
#
# 1. P sits second to the right of U, who sits opposite to T.
# 2. Two persons sit between Q and T.
# 3. S sits third to the right of P.
# 4. V sits second to the left of W.
#
# We are asked to find out how many persons will remain unchanged if all the persons sit alphabetically starting from P in a clockwise direction, except for P itself.
#
# First, let's determine the relative positions of the persons:
#
# - U is opposite T, so they cannot be adjacent (i.e., one to the left or right of the other). Let's place them as far apart as possible while maintaining their opposition. Suppose U sits at position 1 and T sits at position 7.
# - Since P sits second to the right of U, P will sit at position 2.
#
# Next, let's consider S. Given that S is third to the right of P, we can place S between positions 4 and 5 (i.e., one spot after Q and two spots before W). Now, since there are two persons sitting between Q and T, this means Q must sit at position 3 or 6.
#
# Given these conditions, let's analyze all possible arrangements:
#
# - If Q sits at position 3, then V will be at position 1 (second to the left of W), but U is already placed at position 1. So, Q cannot sit at position 3.
# - Therefore, Q must sit at position 6.
#
# Now we can fill in the rest of the table:
#
# - P sits second to the right of U (at position 2).
# - Q sits two spots away from T, so Q is at position 6 and T is opposite it (position 7), but this conflicts with our initial placement of U and T. Thus, we need to re-examine the relative positions of the persons:
#   - If S sits third to the right of P, then S will be between positions 4 and 5.
#   - Since two spots sit between Q and T, Q must be at position 6 and W must be at position 5 (because V sits second to the left of W).
#   - Given these conditions, let's place U at position 1 (opposite T) and T at position 7.
#
# We now have a complete arrangement:
#
# P | Q | R | S | T | U | V | W
#
# This completes our initial assessment. We can now answer the question:
#
# If all persons sit alphabetically starting from P in clockwise direction, then how many will remain unchanged (except for P)?
#
# Based on our analysis, we found that there are no remaining spots left to place anyone else in the same order as given, since Q is at position 6 and U and T have been fixed. Therefore, no one but P can be placed in the same position.
#
# So, the answer should be:
#
# "None"
#
# (Options: ["None", "One", "Two", "Three", "None of these"])
#
# Question description: Eight persons namely P, Q, R, S, T, U, V, and W are sitting around a circular table facing the centre of the table but not necessarily in the same order. P sits second to the right of U, who sits opposite to T. Two persons sit between Q and T. S sits third to the right of P. V sits second to the left of W.
# Question: How many persons sit between P and R, when counted from left of P?
# Options: ["None", "One", "Two", "Three", "None of these"]
# Answer: Let's analyze the given information step by step:
#
# 1. P sits second to the right of U, who sits opposite to T.
# 2. Two persons sit between Q and T.
# 3. S sits third to the right of P.
# 4. V sits second to the left of W.
#
# From statement 1, we can conclude that:
# - U is not adjacent to P (since one person sits between them).
# - The arrangement around the table must be such that P and U are separated by at least two seats in a clockwise direction from their relative positions to each other.
#
# Now, let's consider the seating position of S and P:
# - Since S sits third to the right of P, there must be at least 2 persons between them (including P).
#
# From statement 4, we know that V sits second to the left of W. However, it doesn't provide any information about their positions in relation to P or R.
#
# Now, let's try to deduce the possible position of Q and T:
# - Since two persons sit between Q and T, we can assume they are seated opposite each other (as U is seated opposite to T).
#
# Combining this with statement 1, where U sits opposite to T, it becomes evident that the seating arrangement around the table will have one person sitting between P and R.
#
# From the given options, let's select "One" as our final answer.
#
# Question description: Eight persons namely P, Q, R, S, T, U, V, and W are sitting around a circular table facing the centre of the table but not necessarily in the same order. P sits second to the right of U, who sits opposite to T. Two persons sit between Q and T. S sits third to the right of P. V sits second to the left of W.
# Question: Who sits third to the left of V?
# Options: ["U", "W", "Q", "R", "None of these"]
#
# Answer: Let's analyze the given information step by step:
#
# 1. P sits second to the right of U, who sits opposite to T.
# 2. Two persons sit between Q and T.
# 3. S sits third to the right of P.
# 4. V sits second to the left of W.
#
# From statement (4), we know that V is sitting next to W on the left.
#
# Now, let's consider the options given for the question "Who sits third to the left of V?":
#
# * U
# * W
# * Q
# * R
# * None of these
#
# Since V is sitting second to the left of W (statement 4), we can conclude that there must be one person between V and W on the right side. This person could only be P, as it is not mentioned anywhere else.
#
# Now, looking at the given statements again:
#
# 1. P sits second to the right of U, who sits opposite to T.
# 2. Two persons sit between Q and T.
#
# This implies that T and U are sitting opposite each other, with two people between them (Q).
#
# Considering this arrangement, we can see that R is not possible as it would require three people to be placed in a circular manner (T, U, and the person between Q and T), making no room for P.
#
# The only arrangement possible is:
#
# V - P - U - W
#
# Since there's no one else mentioned who sits two places before V on the left side.
#
# Question description: Eight persons namely P, Q, R, S, T, U, V, and W are sitting around a circular table facing the centre of the table but not necessarily in the same order. P sits second to the right of U, who sits opposite to T. Two persons sit between Q and T. S sits third to the right of P. V sits second to the left of W.
# Question: Who sits opposite to S?
# Options: ["U", "V", "P", "Q", "None of these"]
#
# Answer: Let's analyze the given information:
#
# 1. P sits second to the right of U, who sits opposite to T.
# 2. Two persons sit between Q and T.
# 3. S sits third to the right of P.
# 4. V sits second to the left of W.
#
# From statement 1, we know that U is sitting opposite to T, which means that U and T are on either side of each other around the circular table.
#
# Now, let's look at statement 2: "Two persons sit between Q and T." This implies that there are two people between Q and T in terms of their position around the table. However, it doesn't directly tell us who sits opposite to S.
#
# However, since P is second to the right of U (statement 1), and S is third to the right of P (statement 3), we can infer that S must be sitting somewhere between U and T in terms of their positions around the table.
#
# Given this arrangement, it's clear that T sits opposite to U from statement 1.
#
# So, we need to find out who sits opposite to S given its position relative to P. We already know S is third to the right of P.
#
# Now let's think about possible seating arrangements where these conditions are satisfied:
#
# If we assume U is sitting in position #8 (opposite T), then:
# - The order for the people sitting around the table, starting from 1 and going clockwise, would be: ..., 7, 6, 5, P, S, Q, T, U
#
# Now, if we want to find who sits opposite S, given that S is third to the right of P:
# - Since there are eight people in total (a round table), S must sit on position #4.
#
# If we look at this seating arrangement, it's clear that V and W cannot sit opposite S because they're too far away from each other. The same applies for Q and T since two persons have to sit between them according to statement 2.
#
# So, the only option left is U and T. However, given that P sits second to the right of U (statement 1), it's impossible for V or W to be in position #4.
#
# The most likely candidate would be someone not mentioned yet: U cannot occupy position #5; otherwise, P won't be able to sit two seats away from him.
#
# If we take into account statement 3 again - "Two persons sit between Q and T" - then it's clear that if V sits second to the left of W (statement 4), there is no room for them in the original order unless U, P, S, Q, or T were removed.
#
# Now, thinking back on what was mentioned before: The seating arrangement is as follows:
# ..., 7, 6, 5, P, S, Q, T, U
#
# If we take V and W into account (the fourth and fifth options) in a separate case where the table has only eight people:
# - ..., 7, V, W, 4, 3, 2, 1
#
# This leads us to conclude that there is no more room for P if S sits third to the right of him, as U occupies position #8.
#
# Since this would break condition (c) - "S sits third to the right of P" - we can assume V and W are not occupying positions #4 or #5 either.
#
# The above argument implies that T must be sitting opposite S for the seating arrangement to satisfy all given conditions because it's impossible for U, V, or W to occupy position #5.
#
# So, who sits opposite to S?
#
# From statement 1, we know that T and U sit on either side of each other. If T is in the fifth spot, which makes him sitting across from P, and if two people are between Q and T (statement 2), then only T fits this description as S can't occupy position #4.
#
# Thus, it's possible for V to be second to the left of W (as both appear together on opposite sides in a different seating arrangement).
#
# However, there is one remaining option that has not been eliminated yet - U and T. We already ruled out everyone else.
#
# So our final answer must be...
#
# Question description: A law firm has exactly nine partners: Fox, Glassen, Hae, Inman, Jacoby, Kohn, Lopez, Malloy, and Nassar. Kohn's salary is greater than both Inman's and Lopez's. Lopez's salary is greater than Nassar's. Inman's salary is greater than Fox's. Fox's salary is greater than Malloy's. Malloy's salary is greater than Glassen's. Glassen's salary is greater than Jacoby's. Jacoby's salary is greater than Hae's.
# Question: Which one of the following partners cannot have the third highest salary?
# Options: [ "Fox", "Inman", "Lopez", "Malloy", "Nassar" ]
# Answer: To determine which partner cannot have the third-highest salary, we must analyze the given conditions:
#
# 1. Kohn's salary is greater than both Inman's and Lopez's.
# 2. Lopez's salary is greater than Nassar's.
# 3. Inman's salary is greater than Fox's.
# 4. Fox's salary is greater than Malloy's.
# 5. Malloy's salary is greater than Glassen's.
# 6. Glassen's salary is greater than Jacoby's.
# 7. Jacoby's salary is greater than Hae's.
#
# From condition 1, we know Kohn has a higher salary than both Inman and Lopez. This means that Inman and Lopez cannot have the highest salaries (which are reserved for those with salaries above others), but they can potentially be in the middle if there is another partner above them or below them. Similarly, condition 2 implies Nassar is not among the top three.
#
# Condition 3 establishes a hierarchy where Inman has a higher salary than Fox and thus cannot have the third-highest salary because that would imply a direct relationship with both Kohn and Lopez (neither of which are possible due to conditions 1 and 2).
#
# Similarly, condition 4 sets Fox above Malloy. Since Fox's position relative to other partners is defined but does not establish him as in a middle tier without further context about the salaries of others, we focus on where Inman stands.
#
# Conditions 5 through 7 do provide additional orderings among the remaining partners, but they are more specific and do not directly impact our determination of which partner cannot have the third-highest salary. They essentially describe a broader hierarchy within the group that is already addressed by conditions 1 through 4 in terms of who can be above or below others.
#
# Therefore, based on these conditions, we determine that:
#
# The final answer is: Inman
#
# Question description: A law firm has exactly nine partners: Fox, Glassen, Hae, Inman, Jacoby, Kohn, Lopez, Malloy, and Nassar. Kohn's salary is greater than both Inman's and Lopez's. Lopez's salary is greater than Nassar's. Inman's salary is greater than Fox's. Fox's salary is greater than Malloy's. Malloy's salary is greater than Glassen's. Glassen's salary is greater than Jacoby's. Jacoby's salary is greater than Hae's.
# Question: If Malloy and Nassar earn the same salary, at least how many of the partners must have lower salaries than Lopez?
# Options: [ "3", "4", "5", "6", "7" ]
# Answer: Since Malloy's salary is greater than Glassen's and Glassen's salary is greater than Jacoby's, at least one of these two must have a lower salary than Lopez. Similarly, Hae has a lower salary than Jacoby and Jacoby has a lower salary than Lopez. So at least three must earn lower salaries than Lopez: Nassar (if his salary equals Malloy), Hae, and one of Glassen or Jacoby.
#
# The final answer is: $\boxed{3}$

# %% [markdown]
# # Loop to ask-answer questions continously

# %%
while True:
    print("Say 'exit' or 'quit' to exit the loop")
    question = input('User question: ')
    print(f"Question: {question}")
    if question.lower() in ["exit", "quit"]:
        print("Exiting the conversation. Goodbye!")
        break
    formatted_prompt = prompt.format(context=retrieved_context, question=question)
    response_from_model = model.invoke(formatted_prompt)
    parsed_response = parser.parse(response_from_model)
    print(f"Answer: {parsed_response}")
    print()
# Out:
# Say 'exit' or 'quit' to exit the loop
# Question: exit
# Exiting the conversation. Goodbye!
